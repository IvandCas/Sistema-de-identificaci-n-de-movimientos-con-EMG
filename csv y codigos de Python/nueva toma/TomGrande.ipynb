# %%
import serial
import csv
import time
import keyboard

# Función para obtener el nombre del archivo CSV
def obtener_nombre_archivo(indice):
    return f'datos6s_EMG115200TOMAINDICE{indice}.csv'

# Establecer conexión serial con Arduino
arduino = serial.Serial('COM3', 115200)  # Cambia 'COM6' por el puerto al que está conectado tu Arduino

# Contador para el nombre del archivo
indice_archivo = 401

while True:
    # Nombre del archivo CSV
    nombre_archivo = obtener_nombre_archivo(indice_archivo)

    # Abrir el archivo CSV en modo escritura
    with open(nombre_archivo, mode='w', newline='') as archivo_csv:
        # Crear un objeto escritor CSV
        escritor_csv = csv.writer(archivo_csv)
        
        # Escribir encabezados
        escritor_csv.writerow(['Dato'])

        print(f"Iniciando toma de datos en '{nombre_archivo}'...")
        tiempo_inicial = time.time()  # Guardar el tiempo inicial

        while (time.time() - tiempo_inicial) < 1:
            # Leer línea de datos desde Arduino
            datos = arduino.readline().decode().strip()
            tiempo_actual = time.time() - tiempo_inicial
            
            # Guardar los datos en el archivo CSV
            escritor_csv.writerow([datos])

            # Verificar si se presiona la tecla "Escape" para detener la toma de datos
            if keyboard.is_pressed('esc'):
                break

        print(f"Fin de la toma de datos en '{nombre_archivo}'")

    # Incrementar el contador del nombre del archivo
    indice_archivo += 1

    # Verificar si se presionó la tecla "Escape" para detener la toma de datos
    if keyboard.is_pressed('esc'):
        break

# Cerrar la conexión serial
arduino.close()
# Out:
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE401.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE401.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE402.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE402.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE403.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE403.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE404.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE404.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE405.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE405.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE406.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE406.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE407.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE407.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE408.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE408.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE409.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE409.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE410.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE410.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE411.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE411.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE412.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE412.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE413.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE413.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE414.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE414.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE415.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE415.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE416.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE416.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE417.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE417.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE418.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE418.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE419.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE419.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE420.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE420.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE421.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE421.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE422.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE422.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE423.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE423.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE424.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE424.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE425.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE425.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE426.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE426.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE427.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE427.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE428.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE428.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE429.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE429.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE430.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE430.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE431.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE431.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE432.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE432.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE433.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE433.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE434.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE434.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE435.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE435.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE436.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE436.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE437.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE437.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE438.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE438.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE439.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE439.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE440.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE440.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE441.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE441.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE442.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE442.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE443.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE443.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE444.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE444.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE445.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE445.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE446.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE446.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE447.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE447.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE448.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE448.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE449.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE449.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE450.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE450.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE451.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE451.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE452.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE452.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE453.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE453.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE454.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE454.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE455.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE455.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE456.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE456.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE457.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE457.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE458.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE458.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE459.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE459.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE460.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE460.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE461.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE461.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE462.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE462.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE463.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE463.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE464.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE464.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE465.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE465.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE466.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE466.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE467.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE467.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE468.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE468.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE469.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE469.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE470.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE470.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE471.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE471.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE472.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE472.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE473.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE473.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE474.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE474.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE475.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE475.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE476.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE476.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE477.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE477.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE478.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE478.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE479.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE479.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE480.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE480.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE481.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE481.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE482.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE482.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE483.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE483.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE484.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE484.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE485.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE485.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE486.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE486.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE487.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE487.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE488.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE488.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE489.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE489.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE490.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE490.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE491.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE491.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE492.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE492.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE493.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE493.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE494.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE494.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE495.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE495.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE496.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE496.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE497.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE497.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE498.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE498.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE499.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE499.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE500.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE500.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE501.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE501.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE502.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE502.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE503.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE503.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE504.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE504.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE505.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE505.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE506.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE506.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE507.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE507.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE508.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE508.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE509.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE509.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE510.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE510.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE511.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE511.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE512.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE512.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE513.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE513.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE514.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE514.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE515.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE515.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE516.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE516.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE517.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE517.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE518.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE518.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE519.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE519.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE520.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE520.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE521.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE521.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE522.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE522.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE523.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE523.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE524.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE524.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE525.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE525.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE526.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE526.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE527.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE527.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE528.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE528.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE529.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE529.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE530.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE530.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE531.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE531.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE532.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE532.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE533.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE533.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE534.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE534.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE535.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE535.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE536.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE536.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE537.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE537.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE538.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE538.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE539.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE539.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE540.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE540.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE541.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE541.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE542.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE542.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE543.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE543.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE544.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE544.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE545.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE545.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE546.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE546.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE547.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE547.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE548.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE548.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE549.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE549.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE550.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE550.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE551.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE551.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE552.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE552.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE553.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE553.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE554.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE554.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE555.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE555.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE556.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE556.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE557.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE557.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE558.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE558.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE559.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE559.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE560.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE560.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE561.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE561.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE562.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE562.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE563.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE563.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE564.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE564.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE565.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE565.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE566.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE566.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE567.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE567.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE568.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE568.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE569.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE569.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE570.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE570.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE571.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE571.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE572.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE572.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE573.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE573.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE574.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE574.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE575.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE575.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE576.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE576.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE577.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE577.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE578.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE578.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE579.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE579.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE580.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE580.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE581.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE581.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE582.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE582.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE583.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE583.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE584.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE584.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE585.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE585.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE586.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE586.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE587.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE587.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE588.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE588.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE589.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE589.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE590.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE590.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE591.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE591.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE592.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE592.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE593.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE593.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE594.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE594.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE595.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE595.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE596.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE596.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE597.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE597.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE598.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE598.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE599.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE599.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE600.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE600.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE601.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE601.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAINDICE602.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAINDICE602.csv'

# %%
import serial
import csv
import time
import keyboard

# Función para obtener el nombre del archivo CSV
def obtener_nombre_archivo(indice):
    return f'datos6s_EMG115200TOMAPULGAR{indice}.csv'

# Establecer conexión serial con Arduino
arduino = serial.Serial('COM3', 115200)  # Cambia 'COM6' por el puerto al que está conectado tu Arduino

# Contador para el nombre del archivo
indice_archivo = 401

while True:
    # Nombre del archivo CSV
    nombre_archivo = obtener_nombre_archivo(indice_archivo)

    # Abrir el archivo CSV en modo escritura
    with open(nombre_archivo, mode='w', newline='') as archivo_csv:
        # Crear un bjeto escritor CSV
        escritor_csv = csv.writer(archivo_csv)
        
        # Escribir encabezados
        escritor_csv.writerow(['Dato'])

        print(f"Iniciando toma de datos en '{nombre_archivo}'...")
        tiempo_inicial = time.time()  # Guardar el tiempo inicial

        while (time.time() - tiempo_inicial) < 1:
            # Leer línea de datos desde Arduino
            datos = arduino.readline().decode().strip()
            tiempo_actual = time.time() - tiempo_inicial
            
            # Guardar los datos en el archivo CSV
            escritor_csv.writerow([datos])

            # Verificar si se presiona la tecla "Escape" para detener la toma de datos
            if keyboard.is_pressed('esc'):
                break

        print(f"Fin de la toma de datos en '{nombre_archivo}'")

    # Incrementar el contador del nombre del archivo
    indice_archivo += 1

    # Verificar si se presionó la tecla "Escape" para detener la toma de datos
    if keyboard.is_pressed('esc'):
        break

# Cerrar la conexión serial
arduino.close()
# Out:
# Iniciando toma de datos en 'datos6s_EMG115200TOMAPULGA
csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAPULGAR580.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAPULGAR581.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAPULGAR581.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAPULGAR582.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAPULGAR582.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAPULGAR583.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAPULGAR583.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAPULGAR584.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAPULGAR584.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAPULGAR585.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAPULGAR585.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAPULGAR586.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAPULGAR586.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAPULGAR587.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAPULGAR587.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAPULGAR588.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAPULGAR588.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAPULGAR589.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAPULGAR589.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAPULGAR590.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAPULGAR590.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAPULGAR591.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAPULGAR591.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAPULGAR592.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAPULGAR592.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAPULGAR593.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAPULGAR593.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAPULGAR594.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAPULGAR594.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAPULGAR595.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAPULGAR595.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAPULGAR596.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAPULGAR596.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAPULGAR597.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAPULGAR597.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAPULGAR598.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAPULGAR598.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAPULGAR599.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAPULGAR599.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAPULGAR600.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAPULGAR600.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAPULGAR601.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAPULGAR601.csv'

# %%
import serial
import csv
import time
import keyboard

# Función para obtener el nombre del archivo CSV
def obtener_nombre_archivo(indice):
    return f'datos6s_EMG115200TOMACORAZON{indice}.csv'

# Establecer conexión serial con Arduino
arduino = serial.Serial('COM3', 115200)  # Cambia 'COM6' por el puerto al que está conectado tu Arduino

# Contador para el nombre del archivo
indice_archivo = 401

while True:
    # Nombre del archivo CSV
    nombre_archivo = obtener_nombre_archivo(indice_archivo)

    # Abrir el archivo CSV en modo escritura
    with open(nombre_archivo, mode='w', newline='') as archivo_csv:
        # Crear un bjeto escritor CSV
        escritor_csv = csv.writer(archivo_csv)
        
        # Escribir encabezados
        escritor_csv.writerow(['Dato'])

        print(f"Iniciando toma de datos en '{nombre_archivo}'...")
        tiempo_inicial = time.time()  # Guardar el tiempo inicial

        while (time.time() - tiempo_inicial) < 1:
            # Leer línea de datos desde Arduino
            datos = arduino.readline().decode().strip()
            tiempo_actual = time.time() - tiempo_inicial
            
            # Guardar los datos en el archivo CSV
            escritor_csv.writerow([datos])

            # Verificar si se presiona la tecla "Escape" para detener la toma de datos
            if keyboard.is_pressed('esc'):
                break

        print(f"Fin de la toma de datos en '{nombre_archivo}'")

    # Incrementar el contador del nombre del archivo
    indice_archivo += 1

    # Verificar si se presionó la tecla "Escape" para detener la toma de datos
    if keyboard.is_pressed('esc'):
        break

# Cerrar la conexión serial
arduino.close()
# Out:
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON401.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON401.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON402.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON402.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON403.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON403.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON404.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON404.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON405.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON405.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON406.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON406.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON407.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON407.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON408.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON408.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON409.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON409.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON410.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON410.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON411.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON411.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON412.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON412.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON413.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON413.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON414.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON414.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON415.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON415.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON416.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON416.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON417.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON417.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON418.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON418.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON419.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON419.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON420.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON420.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON421.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON421.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON422.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON422.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON423.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON423.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON424.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON424.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON425.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON425.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON426.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON426.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON427.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON427.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON428.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON428.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON429.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON429.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON430.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON430.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON431.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON431.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON432.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON432.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON433.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON433.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON434.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON434.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON435.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON435.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON436.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON436.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON437.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON437.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON438.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON438.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON439.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON439.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON440.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON440.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON441.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON441.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON442.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON442.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON443.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON443.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON444.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON444.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON445.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON445.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON446.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON446.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON447.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON447.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON448.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON448.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON449.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON449.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON450.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON450.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON451.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON451.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON452.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON452.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON453.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON453.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON454.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON454.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON455.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON455.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON456.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON456.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON457.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON457.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON458.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON458.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON459.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON459.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON460.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON460.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON461.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON461.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON462.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON462.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON463.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON463.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON464.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON464.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON465.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON465.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON466.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON466.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON467.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON467.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON468.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON468.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON469.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON469.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON470.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON470.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON471.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON471.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON472.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON472.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON473.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON473.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON474.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON474.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON475.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON475.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON476.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON476.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON477.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON477.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON478.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON478.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON479.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON479.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON480.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON480.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON481.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON481.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON482.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON482.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON483.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON483.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON484.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON484.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON485.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON485.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON486.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON486.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON487.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON487.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON488.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON488.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON489.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON489.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON490.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON490.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON491.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON491.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON492.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON492.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON493.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON493.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON494.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON494.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON495.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON495.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON496.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON496.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON497.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON497.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON498.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON498.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON499.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON499.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON500.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON500.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON501.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON501.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON502.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON502.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON503.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON503.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON504.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON504.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON505.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON505.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON506.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON506.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON507.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON507.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON508.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON508.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON509.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON509.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON510.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON510.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON511.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON511.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON512.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON512.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON513.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON513.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON514.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON514.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON515.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON515.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON516.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON516.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON517.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON517.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON518.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON518.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON519.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON519.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON520.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON520.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON521.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON521.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON522.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON522.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON523.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON523.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON524.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON524.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON525.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON525.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON526.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON526.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON527.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON527.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON528.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON528.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON529.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON529.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON530.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON530.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON531.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON531.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON532.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON532.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON533.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON533.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON534.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON534.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON535.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON535.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON536.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON536.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON537.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON537.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON538.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON538.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON539.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON539.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON540.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON540.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON541.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON541.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON542.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON542.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON543.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON543.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON544.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON544.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON545.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON545.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON546.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON546.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON547.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON547.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON548.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON548.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON549.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON549.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON550.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON550.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON551.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON551.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON552.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON552.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON553.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON553.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON554.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON554.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON555.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON555.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON556.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON556.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON557.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON557.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON558.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON558.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON559.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON559.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON560.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON560.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON561.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON561.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON562.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON562.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON563.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON563.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON564.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON564.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON565.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON565.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON566.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON566.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON567.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON567.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON568.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON568.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON569.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON569.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON570.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON570.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON571.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON571.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON572.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON572.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON573.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON573.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON574.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON574.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON575.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON575.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON576.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON576.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON577.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON577.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON578.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON578.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON579.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON579.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON580.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON580.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON581.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON581.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON582.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON582.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON583.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON583.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON584.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON584.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON585.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON585.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON586.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON586.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON587.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON587.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON588.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON588.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON589.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON589.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON590.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON590.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON591.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON591.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON592.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON592.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON593.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON593.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON594.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON594.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON595.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON595.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON596.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON596.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON597.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON597.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON598.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON598.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON599.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON599.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON600.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON600.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON601.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON601.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON602.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON602.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON603.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON603.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON604.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON604.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACORAZON605.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACORAZON605.csv'

# %%
import serial
import csv
import time
import keyboard

# Función para obtener el nombre del archivo CSV
def obtener_nombre_archivo(indice):
    return f'datos6s_EMG115200TOMAANULAR{indice}.csv'

# Establecer conexión serial con Arduino
arduino = serial.Serial('COM3', 115200)  # Cambia 'COM6' por el puerto al que está conectado tu Arduino

# Contador para el nombre del archivo
indice_archivo = 401

while True:
    # Nombre del archivo CSV
    nombre_archivo = obtener_nombre_archivo(indice_archivo)

    # Abrir el archivo CSV en modo escritura
    with open(nombre_archivo, mode='w', newline='') as archivo_csv:
        # Crear un objeto escritor CSV
        escritor_csv = csv.writer(archivo_csv)
        
        # Escribir encabezados
        escritor_csv.writerow(['Dato'])

        print(f"Iniciando toma de datos en '{nombre_archivo}'...")
        tiempo_inicial = time.time()  # Guardar el tiempo inicial

        while (time.time() - tiempo_inicial) < 1:
            # Leer línea de datos desde Arduino
csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAANULAR554.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAANULAR555.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAANULAR555.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAANULAR556.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAANULAR556.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAANULAR557.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAANULAR557.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAANULAR558.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAANULAR558.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAANULAR559.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAANULAR559.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAANULAR560.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAANULAR560.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAANULAR561.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAANULAR561.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAANULAR562.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAANULAR562.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAANULAR563.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAANULAR563.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAANULAR564.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAANULAR564.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAANULAR565.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAANULAR565.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAANULAR566.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAANULAR566.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAANULAR567.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAANULAR567.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAANULAR568.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAANULAR568.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAANULAR569.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAANULAR569.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAANULAR570.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAANULAR570.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAANULAR571.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAANULAR571.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAANULAR572.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAANULAR572.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAANULAR573.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAANULAR573.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAANULAR574.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAANULAR574.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAANULAR575.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAANULAR575.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAANULAR576.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAANULAR576.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAANULAR577.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAANULAR577.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAANULAR578.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAANULAR578.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAANULAR579.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAANULAR579.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAANULAR580.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAANULAR580.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAANULAR581.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAANULAR581.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAANULAR582.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAANULAR582.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAANULAR583.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAANULAR583.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAANULAR584.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAANULAR584.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAANULAR585.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAANULAR585.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAANULAR586.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAANULAR586.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAANULAR587.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAANULAR587.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAANULAR588.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAANULAR588.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAANULAR589.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAANULAR589.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAANULAR590.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAANULAR590.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAANULAR591.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAANULAR591.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAANULAR592.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAANULAR592.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAANULAR593.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAANULAR593.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAANULAR594.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAANULAR594.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAANULAR595.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAANULAR595.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAANULAR596.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAANULAR596.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAANULAR597.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAANULAR597.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAANULAR598.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAANULAR598.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAANULAR599.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAANULAR599.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAANULAR600.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAANULAR600.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAANULAR601.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAANULAR601.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAANULAR602.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAANULAR602.csv'

# %%
import serial
import csv
import time
import keyboard

# Función para obtener el nombre del archivo CSV
def obtener_nombre_archivo(indice):
    return f'datos6s_EMG115200TOMAPINZA{indice}.csv'

# Establecer conexión serial con Arduino
arduino = serial.Serial('COM3', 115200)  # Cambia 'COM6' por el puerto al que está conectado tu Arduino

# Contador para el nombre del archivo
indice_archivo = 401

while True:
    # Nombre del archivo CSV
    nombre_archivo = obtener_nombre_archivo(indice_archivo)

    # Abrir el archivo CSV en modo escritura
    with open(nombre_archivo, mode='w', newline='') as archivo_csv:
        # Crear un objeto escritor CSV
        escritor_csv = csv.writer(archivo_csv)
        
        # Escribir encabezados
        escritor_csv.writerow(['Dato'])

        print(f"Iniciando toma de datos en '{nombre_archivo}'...")
        tiempo_inicial = time.time()  # Guardar el tiempo inicial

        while (time.time() - tiempo_inicial) < 1:
            # Leer línea de datos desde Arduino
            datos = arduino.readline().decode().strip()
            tiempo_actual = time.time() - tiempo_inicial
            
            # Guardar los datos en el archivo CSV
            escritor_csv.writerow([datos])

            # Verificar si se presiona la tecla "Escape" para detener la toma de datos
            if keyboard.is_pressed('esc'):
                break

        print(f"Fin de la toma de datos en '{nombre_archivo}'")

    # Incrementar el contador del nombre del archivo
    indice_archivo += 1

    # Verificar si se presionó la tecla "Escape" para detener la toma de datos
    if keyboard.is_pressed('esc'):
        break

# Cerrar la conexión serial
arduino.close()
# Out:
# Iniciando toma de datos en 'datos6s_EMG115200TOMAPINZA401.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAPINZA401.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAPINZA402.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAPINZA402.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAPINZA403.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAPINZA403.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAPINZA404.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAPINZA404.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAPINZA405.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAPINZA405.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAPINZA406.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAPINZA406.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAPINZA407.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAPINZA407.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAPINZA408.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAPINZA408.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAPINZA409.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAPINZA409.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAPINZA410.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAPINZA410.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAPINZA411.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAPINZA411.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAPINZA412.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAPINZA412.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAPINZA413.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAPINZA413.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAPINZA414.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAPINZA414.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAPINZA415.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAPINZA415.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAPINZA416.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAPINZA416.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAPINZA417.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAPINZA417.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAPINZA418.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAPINZA418.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAPINZA419.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAPINZA419.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAPINZA420.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAPINZA420.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAPINZA421.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAPINZA421.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAPINZA422.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAPINZA422.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAPINZA423.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAPINZA423.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAPINZA424.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAPINZA424.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAPINZA425.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAPINZA425.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAPINZA426.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAPINZA426.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAPINZA427.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAPINZA427.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAPINZA428.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAPINZA428.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAPINZA429.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAPINZA429.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAPINZA430.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAPINZA430.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAPINZA431.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAPINZA431.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAPINZA432.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAPINZA432.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAPINZA433.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAPINZA433.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAPINZA434.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAPINZA434.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAPINZA435.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAPINZA435.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAPINZA436.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAPINZA436.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAPINZA437.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAPINZA437.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAPINZA438.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAPINZA438.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAPINZA439.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAPINZA439.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAPINZA440.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAPINZA440.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAPINZA441.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAPINZA441.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAPINZA442.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAPINZA442.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAPINZA443.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAPINZA443.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAPINZA444.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAPINZA444.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAPINZA445.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAPINZA445.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAPINZA446.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAPINZA446.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAPINZA447.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAPINZA447.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAPINZA448.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAPINZA448.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAPINZA449.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAPINZ
    with open(nombre_archivo, mode='w', newline='') as archivo_csv:
        # Crear un objeto escritor CSV
        escritor_csv = csv.writer(archivo_csv)
        
        # Escribir encabezados
        escritor_csv.writerow(['Dato'])

        print(f"Iniciando toma de datos en '{nombre_archivo}'...")
        tiempo_inicial = time.time()  # Guardar el tiempo inicial

        while (time.time() - tiempo_inicial) < 1:
            # Leer línea de datos desde Arduino
            datos = arduino.readline().decode().strip()
            tiempo_actual = time.time() - tiempo_inicial
            
            # Guardar los datos en el archivo CSV
            escritor_csv.writerow([datos])

            # Verificar si se presiona la tecla "Escape" para detener la toma de datos
            if keyboard.is_pressed('esc'):
                break

        print(f"Fin de la toma de datos en '{nombre_archivo}'")

    # Incrementar el contador del nombre del archivo
    indice_archivo += 1

    # Verificar si se presionó la tecla "Escape" para detener la toma de datos
    if keyboard.is_pressed('esc'):
        break

# Cerrar la conexión serial
arduino.close()
# Out:
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA401.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA401.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA402.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA402.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA403.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA403.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA404.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA404.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA405.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA405.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA406.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA406.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA407.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA407.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA408.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA408.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA409.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA409.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA410.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA410.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA411.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA411.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA412.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA412.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA413.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA413.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA414.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA414.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA415.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA415.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA416.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA416.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA417.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA417.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA418.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA418.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA419.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA419.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA420.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA420.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA421.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA421.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA422.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA422.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA423.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA423.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA424.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA424.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA425.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA425.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA426.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA426.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA427.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA427.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA428.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA428.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA429.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA429.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA430.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA430.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA431.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA431.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA432.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA432.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA433.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA433.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA434.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA434.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA435.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA435.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA436.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA436.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA437.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA437.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA438.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA438.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA439.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA439.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA440.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA440.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA441.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA441.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA442.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA442.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA443.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA443.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA444.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA444.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA445.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA445.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA446.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA446.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA447.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA447.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA448.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA448.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA449.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA449.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA450.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA450.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA451.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA451.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA452.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA452.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA453.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA453.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA454.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA454.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA455.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA455.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA456.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA456.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA457.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA457.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA458.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA458.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA459.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA459.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA460.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA460.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA461.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA461.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA462.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA462.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA463.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA463.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA464.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA464.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA465.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA465.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA466.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA466.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA467.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA467.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA468.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA468.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA469.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA469.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA470.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA470.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA471.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA471.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA472.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA472.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA473.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA473.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA474.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA474.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA475.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA475.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA476.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA476.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA477.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA477.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA478.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA478.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA479.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA479.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA480.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA480.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA481.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA481.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA482.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA482.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA483.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA483.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA484.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA484.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA485.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA485.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA486.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA486.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA487.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA487.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA488.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA488.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA489.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA489.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA490.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA490.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA491.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA491.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA492.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA492.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA493.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA493.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA494.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA494.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA495.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA495.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA496.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA496.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA497.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA497.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA498.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA498.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA499.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA499.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA500.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA500.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA501.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA501.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA502.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA502.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA503.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA503.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA504.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA504.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA505.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA505.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA506.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA506.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA507.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA507.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA508.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA508.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA509.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA509.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA510.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA510.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA511.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA511.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA512.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA512.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA513.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA513.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA514.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA514.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA515.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA515.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA516.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA516.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA517.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA517.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA518.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA518.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA519.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA519.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA520.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA520.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA521.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA521.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA522.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA522.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA523.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA523.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA524.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA524.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA525.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA525.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA526.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA526.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA527.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA527.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA528.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA528.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA529.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA529.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA530.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA530.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA531.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA531.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA532.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA532.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA533.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA533.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA534.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA534.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA535.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA535.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA536.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA536.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA537.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA537.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA538.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA538.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA539.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA539.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA540.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA540.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA541.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA541.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA542.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA542.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA543.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA543.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA544.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA544.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA545.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA545.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA546.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA546.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA547.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA547.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA548.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA548.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA549.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA549.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA550.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA550.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA551.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA551.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA552.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA552.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA553.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA553.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA554.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA554.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA555.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA555.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA556.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA556.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA557.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA557.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA558.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA558.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA559.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA559.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA560.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA560.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA561.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA561.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA562.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA562.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA563.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA563.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA564.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA564.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA565.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA565.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA566.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA566.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA567.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA567.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA568.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA568.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA569.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA569.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA570.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA570.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA571.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA571.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA572.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA572.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA573.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA573.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA574.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA574.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA575.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA575.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA576.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA576.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA577.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA577.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA578.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA578.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA579.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA579.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA580.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA580.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA581.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA581.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA582.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA582.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA583.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA583.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA584.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA584.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA585.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA585.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA586.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA586.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA587.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA587.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA588.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA588.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA589.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA589.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA590.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA590.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA591.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA591.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA592.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA592.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA593.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA593.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA594.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA594.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA595.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA595.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA596.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA596.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA597.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA597.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA598.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA598.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA599.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA599.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA600.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA600.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA601.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA601.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMACERRADA602.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMACERRADA602.csv'

# %%
import serial
import csv
import time
import keyboard

# Función para obtener el nombre del archivo CSV
def obtener_nombre_archivo(indice):
    return f'datos6s_EMG115200TOMAABIERTA{indice}.csv'

# Establecer conexión serial con Arduino
arduino = serial.Serial('COM3', 115200)  # Cambia 'COM6' por el puerto al que está conectado tu Arduino

# Contador para el nombre del archivo
indice_archivo = 401

while True:
    # Nombre del archivo CSV
    nombre_archivo = obtener_nombre_archivo(indice_archivo)

    # Abrir el archivo CSV en modo escritura
    with open(nombre_archivo, mode='w', newline='') as archivo_csv:
        # Crear un objeto escritor CSV
        escritor_csv = csv.writer(archivo_csv)
        
        # Escribir encabezados
        escritor_csv.writerow(['Dato'])

        print(f"Iniciando toma de datos en '{nombre_archivo}'...")
        tiempo_inicial = time.time()  # Guardar el tiempo inicial

        while (time.time() - tiempo_inicial) < 1:
            # Leer línea de datos desde Arduino
            datos = arduino.readline().decode().strip()
            tiempo_actual = time.time() - tiempo_inicial
            
            # Guardar los datos en el archivo CSV
            escritor_csv.writerow([datos])

            # Verificar si se presiona la tecla "Escape" para detener la toma de datos
            if keyboard.is_pressed('esc'):
                break

        print(f"Fin de la toma de datos en '{nombre_archivo}'")

    # Incrementar el contador del nombre del archivo
    indice_archivo += 1

    # Verificar si se presionó la tecla "Escape" para detener la toma de datos
    if keyboard.is_pressed('esc'):
        break

# Cerrar la conexión serial
arduino.close()
# Out:
# Iniciando toma de datos en 'datos6s_EMG115200TOMAABIERTA401.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAABIERTA401.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAABIERTA402.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAABIERTA402.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAABIERTA403.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAABIERTA403.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAABIERTA404.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAABIERTA404.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAABIERTA405.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAABIERTA405.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAABIERTA406.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAABIERTA406.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAABIERTA407.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAABIERTA407.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAABIERTA408.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAABIERTA408.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAABIERTA409.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAABIERTA409.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAABIERTA410.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAABIERTA410.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAABIERTA411.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAABIERTA411.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAABIERTA412.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAABIERTA412.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAABIERTA413.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAABIERTA413.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAABIERTA414.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAABIERTA414.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAABIERTA415.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAABIERTA415.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAABIERTA416.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAABIERTA416.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAABIERTA417.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAABIERTA417.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAABIERTA418.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAABIERTA418.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAABIERTA419.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAABIERTA419.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAABIERTA420.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAABIERTA420.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAABIERTA421.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAABIERTA421.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAABIERTA422.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAABIERTA422.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAABIERTA423.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAABIERTA423.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAABIERTA424.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAABIERTA424.csv'
# Iniciando toma de datos en 'datos6s_EMG115200TOMAABIERTA425.csv'...
# Fin de la toma de datos en 'datos6s_EMG115200TOMAABIERT